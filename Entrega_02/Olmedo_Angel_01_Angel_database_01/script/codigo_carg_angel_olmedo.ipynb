# %%
import pandas as pd

# Cargar la base de datos limpia con el nombre actualizado
df = pd.read_csv('Olmedo_Angel_basededatoslimpia.csv')

# Visualizar las primeras 5 filas para comprobar las nuevas columnas
df.head()
