# %%
import pandas as pd

# Cargar la primera base de datos limpia
df_generaciones = pd.read_csv('resumen de generaciones_database_limpia.csv')

# Cargar la segunda base de datos limpia
df_partidos = pd.read_csv('partidos_database_limpia.csv')

# Visualizar las primeras filas para comprobar la carga de ambas
print("Base de Generaciones:")
display(df_generaciones.head())

print("\nBase de Partidos:")
display(df_partidos.head())
